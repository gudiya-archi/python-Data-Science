# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python_Pandas_date_and_time03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Timestamp Object
# * time stamps reference particular moments in time
# * (e.g, Oct 24th,2022 at 7.00pm)

# %% [markdown]
# # Creating timestamp objects

# %% [markdown]
# * creating a timestamp
# * variations
# * only year
# * using text
# * providing time also

# %%
# creating a timestamp
pd.Timestamp('2026/07/4')
# Out:
# Timestamp('2026-07-04 00:00:00')

# %%
type(pd.Timestamp('2026/07/4'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# variations
print(pd.Timestamp('2026-07-4'))
print(pd.Timestamp('2026/7/4'))
# Out:
# 2026-07-04 00:00:00
# 2026-07-04 00:00:00

# %%
print(pd.Timestamp('2026, 7, 4'))
# Out:
# 2026-07-04 00:00:00

# %% [markdown]
# # only year

# %%
# only year
pd.Timestamp('2026')
# Out:
# Timestamp('2026-01-01 00:00:00')

# %% [markdown]
# # using text

# %%
# using text
pd.Timestamp('5th January 2026')
# Out:
# Timestamp('2026-01-05 00:00:00')

# %%
# providing time also
pd.Timestamp(2026, 1, 5)
# Out:
# Timestamp('2026-01-05 00:00:00')

# %%
# providing time also
pd.Timestamp(2026, 1, 5, 9,21 )
# Out:
# Timestamp('2026-01-05 09:21:00')

# %%
pd.Timestamp('5th January 2026 9:21PM')
# Out:
# Timestamp('2026-01-05 21:21:00')

# %%
pd.Timestamp('5th January 2026 9:21AM')
# Out:
# Timestamp('2026-01-05 09:21:00')

# %%
pd.Timestamp(2026/1/5)
# Out:
# Timestamp('1970-01-01 00:00:00.000000405')

# %% [markdown]
# # using datetime.datetime object
# # import datetime as dt

# %%
# using datetimme.datetime object
import datetime as dt
my_date = dt.datetime(2026, 1, 5, 9, 21)
pd.Timestamp(my_date)
# Out:
# Timestamp('2026-01-05 09:21:00')

# %%
pd.Timestamp(dt.datetime(2026, 1, 5, 9, 21))
# Out:
# Timestamp('2026-01-05 09:21:00')

# %%
# using datetimme.datetime object
x = pd.Timestamp(dt.datetime(2026, 1, 5, 9, 21))
x
# Out:
# Timestamp('2026-01-05 09:21:00')

# %%
# fetching attributes
print(x.year)
print(x.month)
print(x.day)
print(x.hour)
print(x.minute)
print(x.second)
# Out:
# 2026
# 1
# 5
# 9
# 21
# 0

# %% [markdown]
# # Why separates objects to handle data and time when python already has datatime functionality?

# %% [markdown]
# * syntax wise datetime is very convenient
# * but the performance takes a hit while working with huge data. list vs numpy array
# * the weaknesses of Python's datetime formate inspired the Numpy team to add a set of native time series data type to Numpy
# * the datetime 64 dtype encodes dates as 64-bit integer, and thus allows arrays of dates to be represented very compactly.

# %%
import numpy as np
date = np.array('2026-07-04', dtype=np.datetime64)
date
# Out:
# array('2026-07-04', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2026-07-04', '2026-07-05', '2026-07-06', '2026-07-07',
#        '2026-07-08', '2026-07-09', '2026-07-10', '2026-07-11',
#        '2026-07-12', '2026-07-13', '2026-07-14', '2026-07-15'],
#       dtype='datetime64[D]')

# %% [markdown]
# * Because of the uniform type in Numpy datetime64 arrays , this type of opertion can be accomplished much more quickly than if we were working directly with python datatime objects , especially as arrys get large
#
# * pandas timestamp object combines the ease-of-use of python datetimewith the efficient storage and vectorized interface of numpy.datetime64
#
# * from  a group of these timestamp objects, pandas can construct a Datetimeindex that can be used to index data in a series or dataframe

# %% [markdown]
# # DatetimeIndex Object

# %% [markdown]
# # A Collection of pandas timestamp
# * from string
# * using python datetime object
# * using pd.timestamps
# * using datetimeindex as series index

# %%
# from strings
pd.DatetimeIndex(['2026-07-04', '2025-09-05', '2024-08-06'])
# Out:
# DatetimeIndex(['2026-07-04', '2025-09-05', '2024-08-06'], dtype='datetime64[ns]', freq=None)

# %%
# from strings
pd.DatetimeIndex(['2026-07-04', '2025-09-05', '2024-08-06'])  [0]
# Out:
# Timestamp('2026-07-04 00:00:00')

# %%
type(pd.DatetimeIndex(['2026-07-04', '2025-09-05', '2024-08-06']))
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# using python datetime object
pd.DatetimeIndex([dt.datetime(2026, 7, 4), dt.datetime(2025, 9, 5), dt.datetime(2024, 8, 6)])
# Out:
# DatetimeIndex(['2026-07-04', '2025-09-05', '2024-08-06'], dtype='datetime64[ns]', freq=None)

# %%
# using pd.timestamps
pd.DatetimeIndex([pd.Timestamp(2026, 7, 4), pd.Timestamp(2025, 9, 5), pd.Timestamp(2024, 8, 6)])
# Out:
# DatetimeIndex(['2026-07-04', '2025-09-05', '2024-08-06'], dtype='datetime64[ns]', freq=None)

# %%
# using pd.timestamps
pd.DatetimeIndex([pd.Timestamp(2026, 7, 4), pd.Timestamp(2025, 9, 5), pd.Timestamp(2024, 8, 6)])

# %%
# using pd.timestamps
dt_index = pd.DatetimeIndex([pd.Timestamp(2026, 7, 4), pd.Timestamp(2025, 9, 5), pd.Timestamp(2024, 8, 6)])

# %%
# using datetimeindex as series index
pd.Series(data=[1,2,3], index=dt_index)
# Out:
# 2026-07-04    1
# 2025-09-05    2
# 2024-08-06    3
# dtype: int64

# %% [markdown]
# # date_range function

# %% [markdown]
# # generate daily dates in a given range

# %%
# generate daily dates in a given range
pd.date_range(start='2026-07-01', end='2026-07-31', freq='D')
# Out:
# DatetimeIndex(['2026-07-01', '2026-07-02', '2026-07-03', '2026-07-04',
#                '2026-07-05', '2026-07-06', '2026-07-07', '2026-07-08',
#                '2026-07-09', '2026-07-10', '2026-07-11', '2026-07-12',
#                '2026-07-13', '2026-07-14', '2026-07-15', '2026-07-16',
#                '2026-07-17', '2026-07-18', '2026-07-19', '2026-07-20',
#                '2026-07-21', '2026-07-22', '2026-07-23', '2026-07-24',
#                '2026-07-25', '2026-07-26', '2026-07-27', '2026-07-28',
#                '2026-07-29', '2026-07-30', '2026-07-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
# generate daily dates in a given range
pd.date_range(start='2026-07-01', end='2026-08-28', freq='D')
# Out:
# DatetimeIndex(['2026-07-01', '2026-07-02', '2026-07-03', '2026-07-04',
#                '2026-07-05', '2026-07-06', '2026-07-07', '2026-07-08',
#                '2026-07-09', '2026-07-10', '2026-07-11', '2026-07-12',
#                '2026-07-13', '2026-07-14', '2026-07-15', '2026-07-16',
#                '2026-07-17', '2026-07-18', '2026-07-19', '2026-07-20',
#                '2026-07-21', '2026-07-22', '2026-07-23', '2026-07-24',
#                '2026-07-25', '2026-07-26', '2026-07-27', '2026-07-28',
#                '2026-07-29', '2026-07-30', '2026-07-31', '2026-08-01',
#                '2026-08-02', '2026-08-03', '2026-08-04', '2026-08-05',
#                '2026-08-06', '2026-08-07', '2026-08-08', '2026-08-09',
#                '2026-08-10', '2026-08-11', '2026-08-12', '2026-08-13',
#                '2026-08-14', '2026-08-15', '2026-08-16', '2026-08-17',
#                '2026-08-18', '2026-08-19', '2026-08-20', '2026-08-21',
# ...

# %%
# generate daily dates in a given range
pd.date_range(start='2026-07-01', end='2026-08-28', freq='2D')
# Out:
# DatetimeIndex(['2026-07-01', '2026-07-03', '2026-07-05', '2026-07-07',
#                '2026-07-09', '2026-07-11', '2026-07-13', '2026-07-15',
#                '2026-07-17', '2026-07-19', '2026-07-21', '2026-07-23',
#                '2026-07-25', '2026-07-27', '2026-07-29', '2026-07-31',
#                '2026-08-02', '2026-08-04', '2026-08-06', '2026-08-08',
#                '2026-08-10', '2026-08-12', '2026-08-14', '2026-08-16',
#                '2026-08-18', '2026-08-20', '2026-08-22', '2026-08-24',
#                '2026-08-26', '2026-08-28'],
#               dtype='datetime64[ns]', freq='2D')

# %%
# alternate days in a given range
pd.date_range(start='2026-07-01', end='2026-08-28', freq='3D')
# Out:
# DatetimeIndex(['2026-07-01', '2026-07-04', '2026-07-07', '2026-07-10',
#                '2026-07-13', '2026-07-16', '2026-07-19', '2026-07-22',
#                '2026-07-25', '2026-07-28', '2026-07-31', '2026-08-03',
#                '2026-08-06', '2026-08-09', '2026-08-12', '2026-08-15',
#                '2026-08-18', '2026-08-21', '2026-08-24', '2026-08-27'],
#               dtype='datetime64[ns]', freq='3D')

# %% [markdown]
# # B ---> business days

# %%
# B---> business days
pd.date_range(start='2026-07-01', end='2026-08-28', freq='B')
# Out:
# DatetimeIndex(['2026-07-01', '2026-07-02', '2026-07-03', '2026-07-06',
#                '2026-07-07', '2026-07-08', '2026-07-09', '2026-07-10',
#                '2026-07-13', '2026-07-14', '2026-07-15', '2026-07-16',
#                '2026-07-17', '2026-07-20', '2026-07-21', '2026-07-22',
#                '2026-07-23', '2026-07-24', '2026-07-27', '2026-07-28',
#                '2026-07-29', '2026-07-30', '2026-07-31', '2026-08-03',
#                '2026-08-04', '2026-08-05', '2026-08-06', '2026-08-07',
#                '2026-08-10', '2026-08-11', '2026-08-12', '2026-08-13',
#                '2026-08-14', '2026-08-17', '2026-08-18', '2026-08-19',
#                '2026-08-20', '2026-08-21', '2026-08-24', '2026-08-25',
#                '2026-08-26', '2026-08-27', '2026-08-28'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# # W --> one week per day

# %%
# W --> one week per day
pd.date_range(start='2026-07-01', end='2026-08-28', freq='W')
# Out:
# DatetimeIndex(['2026-07-05', '2026-07-12', '2026-07-19', '2026-07-26',
#                '2026-08-02', '2026-08-09', '2026-08-16', '2026-08-23'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start='2026-07-01', end='2026-08-28', freq='W-THU')
# Out:
# DatetimeIndex(['2026-07-02', '2026-07-09', '2026-07-16', '2026-07-23',
#                '2026-07-30', '2026-08-06', '2026-08-13', '2026-08-20',
#                '2026-08-27'],
#               dtype='datetime64[ns]', freq='W-THU')

# %% [markdown]
# # H ---> Hourly date (factor)

# %%
# H --> hourly date (factor)
pd.date_range(start='2026-07-01', end='2026-08-28', freq='H')
# Out:
# /tmp/ipykernel_7908/427762530.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2026-07-01', end='2026-08-28', freq='H')
# DatetimeIndex(['2026-07-01 00:00:00', '2026-07-01 01:00:00',
#                '2026-07-01 02:00:00', '2026-07-01 03:00:00',
#                '2026-07-01 04:00:00', '2026-07-01 05:00:00',
#                '2026-07-01 06:00:00', '2026-07-01 07:00:00',
#                '2026-07-01 08:00:00', '2026-07-01 09:00:00',
#                ...
#                '2026-08-27 15:00:00', '2026-08-27 16:00:00',
#                '2026-08-27 17:00:00', '2026-08-27 18:00:00',
#                '2026-08-27 19:00:00', '2026-08-27 20:00:00',
#                '2026-08-27 21:00:00', '2026-08-27 22:00:00',
#                '2026-08-27 23:00:00', '2026-08-28 00:00:00'],
#               dtype='datetime64[ns]', length=1393, freq='h')

# %%
pd.date_range(start='2026-07-01', end='2026-08-28', freq='6H')
# Out:
# /tmp/ipykernel_7908/2491477144.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2026-07-01', end='2026-08-28', freq='6H')
# DatetimeIndex(['2026-07-01 00:00:00', '2026-07-01 06:00:00',
#                '2026-07-01 12:00:00', '2026-07-01 18:00:00',
#                '2026-07-02 00:00:00', '2026-07-02 06:00:00',
#                '2026-07-02 12:00:00', '2026-07-02 18:00:00',
#                '2026-07-03 00:00:00', '2026-07-03 06:00:00',
#                ...
#                '2026-08-25 18:00:00', '2026-08-26 00:00:00',
#                '2026-08-26 06:00:00', '2026-08-26 12:00:00',
#                '2026-08-26 18:00:00', '2026-08-27 00:00:00',
#                '2026-08-27 06:00:00', '2026-08-27 12:00:00',
#                '2026-08-27 18:00:00', '2026-08-28 00:00:00'],
#               dtype='datetime64[ns]', length=233, freq='6h')

# %% [markdown]
# # M --> month end

# %%
#  M --> month end
pd.date_range(start='2026-07-01', end='2026-08-28', freq='M')
# Out:
# /tmp/ipykernel_7908/1550541124.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start='2026-07-01', end='2026-08-28', freq='M')
# DatetimeIndex(['2026-07-31'], dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# # MS --> year start

# %%
pd.date_range(start='2026-07-01', end='2026-08-28', freq='MS')
# Out:
# DatetimeIndex(['2026-07-01', '2026-08-01'], dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# # A --> year end

# %%
pd.date_range(start='2026-07-01', end='2030-08-28', freq='A')
# Out:
# /tmp/ipykernel_7908/1222637715.py:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   pd.date_range(start='2026-07-01', end='2030-08-28', freq='A')
# DatetimeIndex(['2026-12-31', '2027-12-31', '2028-12-31', '2029-12-31'], dtype='datetime64[ns]', freq='YE-DEC')

# %% [markdown]
# # using periods (number of results)

# %%
pd.date_range(start='2026-07-01', periods=25, freq='D')
# Out:
# DatetimeIndex(['2026-07-01', '2026-07-02', '2026-07-03', '2026-07-04',
#                '2026-07-05', '2026-07-06', '2026-07-07', '2026-07-08',
#                '2026-07-09', '2026-07-10', '2026-07-11', '2026-07-12',
#                '2026-07-13', '2026-07-14', '2026-07-15', '2026-07-16',
#                '2026-07-17', '2026-07-18', '2026-07-19', '2026-07-20',
#                '2026-07-21', '2026-07-22', '2026-07-23', '2026-07-24',
#                '2026-07-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2026-07-01', periods=25, freq='H')
# Out:
# /tmp/ipykernel_7908/1667190132.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2026-07-01', periods=25, freq='H')
# DatetimeIndex(['2026-07-01 00:00:00', '2026-07-01 01:00:00',
#                '2026-07-01 02:00:00', '2026-07-01 03:00:00',
#                '2026-07-01 04:00:00', '2026-07-01 05:00:00',
#                '2026-07-01 06:00:00', '2026-07-01 07:00:00',
#                '2026-07-01 08:00:00', '2026-07-01 09:00:00',
#                '2026-07-01 10:00:00', '2026-07-01 11:00:00',
#                '2026-07-01 12:00:00', '2026-07-01 13:00:00',
#                '2026-07-01 14:00:00', '2026-07-01 15:00:00',
#                '2026-07-01 16:00:00', '2026-07-01 17:00:00',
#                '2026-07-01 18:00:00', '2026-07-01 19:00:00',
#                '2026-07-01 20:00:00', '2026-07-01 21:00:00',
#                '2026-07-01 22:00:00', '2026-07-01 23:00:00',
#                '2026-07-02 00:00:00'],
# ...

# %%
pd.date_range(start='2026-07-01', periods=25, freq='6H')
# Out:
# /tmp/ipykernel_7908/2441672011.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range(start='2026-07-01', periods=25, freq='6H')
# DatetimeIndex(['2026-07-01 00:00:00', '2026-07-01 06:00:00',
#                '2026-07-01 12:00:00', '2026-07-01 18:00:00',
#                '2026-07-02 00:00:00', '2026-07-02 06:00:00',
#                '2026-07-02 12:00:00', '2026-07-02 18:00:00',
#                '2026-07-03 00:00:00', '2026-07-03 06:00:00',
#                '2026-07-03 12:00:00', '2026-07-03 18:00:00',
#                '2026-07-04 00:00:00', '2026-07-04 06:00:00',
#                '2026-07-04 12:00:00', '2026-07-04 18:00:00',
#                '2026-07-05 00:00:00', '2026-07-05 06:00:00',
#                '2026-07-05 12:00:00', '2026-07-05 18:00:00',
#                '2026-07-06 00:00:00', '2026-07-06 06:00:00',
#                '2026-07-06 12:00:00', '2026-07-06 18:00:00',
#                '2026-07-07 00:00:00'],
# ...

# %%
pd.date_range(start='2026-07-01', periods=25, freq='M')
# Out:
# /tmp/ipykernel_7908/698339287.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range(start='2026-07-01', periods=25, freq='M')
# DatetimeIndex(['2026-07-31', '2026-08-31', '2026-09-30', '2026-10-31',
#                '2026-11-30', '2026-12-31', '2027-01-31', '2027-02-28',
#                '2027-03-31', '2027-04-30', '2027-05-31', '2027-06-30',
#                '2027-07-31', '2027-08-31', '2027-09-30', '2027-10-31',
#                '2027-11-30', '2027-12-31', '2028-01-31', '2028-02-29',
#                '2028-03-31', '2028-04-30', '2028-05-31', '2028-06-30',
#                '2028-07-31'],
#               dtype='datetime64[ns]', freq='ME')

# %% [markdown]
# # to_datetime function

# %% [markdown]
# # converts an existing objects to pandas timestamp / datetimeindex object

# %%
# simple series example
s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])

# %%
s
# Out:
# 0    2023/1/1
# 1    2022/1/1
# 2    2021/1/1
# dtype: object

# %%
# simple series example
s = pd.Series(['2023/1/1','2022/1/1','2021/1/1'])
pd.to_datetime(s)
# Out:
# 0   2023-01-01
# 1   2022-01-01
# 2   2021-01-01
# dtype: datetime64[ns]

# %%
pd.to_datetime(s).dt.year
# Out:
# 0    2023
# 1    2022
# 2    2021
# dtype: int32

# %%
pd.to_datetime(s).dt.month
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int32

# %%
pd.to_datetime(s).dt.day
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int32

# %%
pd.to_datetime(s).dt.day_name()
# Out:
# 0      Sunday
# 1    Saturday
# 2      Friday
# dtype: object

# %%
pd.to_datetime(s).dt.month_name()
# Out:
# 0    January
# 1    January
# 2    January
# dtype: object

# %%
# with error
s = pd.Series(['2023/1/1','2022/1/1','2021/130/1'])
s
# Out:
# 0      2023/1/1
# 1      2022/1/1
# 2    2021/130/1
# dtype: object

# %%
# pd.to_datetime(s)
pd.to_datetime(s, errors='coerce')
# Out:
# 0   2023-01-01
# 1   2022-01-01
# 2          NaT
# dtype: datetime64[ns]

# %%
# pd.to_datetime(s)
pd.to_datetime(s, errors='coerce').dt.month
# Out:
# 0    1.0
# 1    1.0
# 2    NaN
# dtype: float64
