# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.python output

# %%
# python is a case sensitive language
print ('hello world')
# Out:
# hello world

# %%
print(archi jaiswal  )
# Out:
#   File "/tmp/ipykernel_15560/1812965813.py", line 1
#     print(archi jaiswal  )
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4,5.4,True )
# Out:
# Hello 1 4 5.4 True

# %%
print('Hello',1,4,5.4,True,sep='/')
# Out:
# Hello/1/4/5.4/True

# %%
print('archi')
print('jaiswal')
# Out:
# archi
# jaiswal

# %%
print('archi',end='-')
print('jaiswal')
# Out:
# archi-jaiswal

# %% [markdown]
# 2. Data types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
print(1e308)
# Out:
# 8
# inf
# 1e+308

# %%
# Decimal/float
print(8.55)
print(1.7e308)
# Out:
# 8.55
# 1.7e+308

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# text/String
print("Hello world")
# Out:
# Hello world

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# list-->C-->Array

# its used for square braket
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tupe  ---> only braket used hota hai <---
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# sets --- curly braces <---
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary --- curly braces used <--
print({"name":"archi","gender":"female", 'weight':45})
# Out:
# {'name': 'archi', 'gender': 'female', 'weight': 45}

# %%
# type
type(1)
type(2.0)
type(True)
type("hello")
type(5+6j)
type([1,2,3])
type((1,2,3))
type({1,2,3})
type({'name':"archi",'gender':'Female','weight':45})
# Out:
# dict

# %%
print (type(1))
# Out:
# <class 'int'>

# %% [markdown]
# 3. Variables

# %%
# static vs Dynamic typing
# static vs Dynamic Binding
# stylish declaration techniques

# %%
name = 'archi'
print(name)
# Out:
# archi

# %%
a = 5
b = 6
print (a+b)
# Out:
# 11

# %%
# Dynamic typing is used in python
a = 5
# Static typing is used in c , c++
# int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'archi'
print(a)

# Static Binding
# int  a = 5
# Out:
# 5
# archi

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a, b, c = 1, 2, 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=  5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# 4. Keywords & Identifiers

# %%
# keywords

# %%
# Identifiers
# you can't start with a digit
1name = 'archi'
print(1name)
# Out:
#   File "/tmp/ipykernel_15560/3450763197.py", line 3
#     1name = 'archi'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = 'archi'
print(name1)
# Out:
# archi

# %%
# you can use special chars --> _
first-name = 'archi'
print(first-name)
# Out:
#   File "/tmp/ipykernel_15560/347441332.py", line 2
#     first-name = 'archi'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
first_name = 'archi'
print(first_name)
# Out:
# archi

# %%
_archi = 'jaiswal'
print(_archi)
# Out:
# jaiswal

# %%
# Identifiers can be a combination of letters in lowercase (a to z) or uppercase (A to Z)
# identifiers can not be keyword

# %%
# identier

# %% [markdown]
# Comments

# %%
# this is a comment
a = 4
b = 6 # like this we can write a comment
print (a+b)
# Out:
# 10

# %% [markdown]
# 5. User Input

# %%
# static vs Dynamic
input('Enter Email')
# Out:
# Enter Emailjaiswalarchi2002@gmail.com
# 'jaiswalarchi2002@gmail.com'

# %%
input(' Enter Email')
# Out:
#  Enter Emailjaiswalarchi2002@gmail.com
# 'jaiswalarchi2002@gmail.com'

# %%
# take input from users and store them in a variable
fnum = input (' Enter first number')
snum = input (' Enter second number')

# print (fnum , snum)
# print (type (fnum),type (snum))
#print (type (int(fnum)),type (int(snum)))

# add the 2 variable
result = int (fnum) + int (snum)

# print the result
print(result)
print(type(fnum))
# Out:
#  Enter first number67
#  Enter second number87
# 154
# <class 'str'>

# %%
# take input from users and store them in a variable
fnum = int ( input (' Enter first number'))
snum = int( input (' Enter second number'))

# print (fnum , snum)
# print (type (fnum),type (snum))
#print (type (int(fnum)),type (int(snum)))

# add the 2 variable
result =  (fnum) + (snum)

# print the result
print(result)
print(type(fnum))
# Out:
#  Enter first number34
#  Enter second number56
# 90
# <class 'int'>

# %% [markdown]
# 6. Type Conversion

# %%
# Implicit vs Explicit

print (5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
print (4 + '4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15560/501787291.py in <cell line: 0>()
# ----> 1 print (4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str --> int
int ('4')
# Out:
# 4

# %%
type(int('4'))
# Out:
# int

# %%
type(int(4.5))
# Out:
# int

# %%
int(4.5)
# Out:
# 4

# %%
int(4+5j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15560/1226094765.py in <cell line: 0>()
# ----> 1 int(4+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
# int to str
str(5)
# type(str(4))
# Out:
# '5'

# %%
# float
float(4)
# Out:
# 4.0

# %% [markdown]
# 7.Literals

# %%
a = 0b1010 #Binary Literals
b = 100   # Decimal Literal
c = 0o310  # Octal Literal
d = 0x12c  # Hexadecimal Literal


# Float Literal
float_1 = 10.5
float_2 = 1.5e2  # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

# Complex Literal
x = 3.14j


print (a,b,c,d)
print (float_1,float_2,float_3)
print (x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# binary
a = 0b1010
print(a)
# Out:
# 10

# %%
c = 0o310
print(c)
# Out:
# 200

# %%
x = 3.14j
print(x)
# Out:
# 3.14j

# %%
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is python '
strings = "this is python"
char = "C"
multiline_str = """ this is a multiline string with more
 than one line code . """
unicode = u"\U0001f600\U0001F606\U0001F923:"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is python
# this is python
# C
#  this is a multiline string with more
#  than one line code .
# 😀😆🤣:
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:",a)
print("b",b)
# Out:
# a: 5
# b 10

# %%
a = None
print (a )
# Out:
# None

# %%
k =
a = 5
b = 6
print('program exe')
# Out:
#   File "/tmp/ipykernel_15560/868913166.py", line 1
#     k =
#         ^
# SyntaxError: invalid syntax

# %%
k = None
a = 5
b = 6
print('program exe')
# Out:
# program exe
