# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.python output

# %%
# python is a case sensitive language
print ('hello world')
# Out:
# hello world

# %%
print(archi jaiswal  )
# Out:
#   File "/tmp/ipykernel_9815/1812965813.py", line 1
#     print(archi jaiswal  )
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4,5.4,True )
# Out:
# Hello 1 4 5.4 True

# %%
print('Hello',1,4,5.4,True,sep='/')
# Out:
# Hello/1/4/5.4/True

# %%
print('archi')
print('jaiswal')
# Out:
# archi
# jaiswal

# %%
print('archi',end='-')
print('jaiswal')
# Out:
# archi-jaiswal

# %% [markdown]
# 2. Data types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
print(1e308)
# Out:
# 8
# inf
# 1e+308

# %%
# Decimal/float
print(8.55)
print(1.7e308)
# Out:
# 8.55
# 1.7e+308

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# text/String
print("Hello world")
# Out:
# Hello world

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# list-->C-->Array

# its used for square braket
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tupe  ---> only braket used hota hai <---
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# sets --- curly braces <---
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary --- curly braces used <--
print({"name":"archi","gender":"female", 'weight':45})
# Out:
# {'name': 'archi', 'gender': 'female', 'weight': 45}

# %%
# type
type(1)
type(2.0)
type(True)
type("hello")
type(5+6j)
type([1,2,3])
type((1,2,3))
type({1,2,3})
type({'name':"archi",'gender':'Female','weight':45})
# Out:
# dict

# %%
print (type(1))
# Out:
# <class 'int'>

# %% [markdown]
# 3. Variables

# %%
# static vs Dynamic typing
# static vs Dynamic Binding
# stylish declaration techniques
