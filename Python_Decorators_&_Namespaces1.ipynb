# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python_Decorators_%26_Namespaces1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Namespaces
#
# A namespace is a space that holds names(identifiers). programmatically speaking , namespaces are dicitionary of identifiers(keys)
# and their objects(values)

# %% [markdown]
# # there are 4 types of namespaces:

# %% [markdown]
# * Builtin Namespace
# * Global Namespace
# * Enclosing Namespace
# * Local Namespace

# %% [markdown]
# # Scope and LEGB Rule
#
# A scope is a textual region of a python program where a namespace is directly accessible.
#
# the interpreter searches for a name from the inside out, looking in the local, enclosing, global and finally the built-in-scope . if the interpreter doesn't find the name in any of these locations, then python raises a NameError exception.

# %%
 # local and global

a = 2
# -----> global variable

def temp():
  # ----> local variable
  b = 3
  print(b)

temp()
print(a)
# Out:
# 3
# 2

# %%
 # local and global same

a = 2
# -----> global variable

def temp():
  # ----> local variable
  a = 3
  print(a)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global ---> local does not have but global has

 # local and global

a = 2
# -----> global variable

def temp():
  # ----> local variable
  print(a)

temp()
print(a)
# Out:
# 2
# 2

# %%
# local and global ---> editing global
# derect changes nhi kr sakte hai
a = 2

def temp():   # ----> local var
  a += 1
  print(a)


temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_3559/195080578.py in <cell line: 0>()
#       8
#       9
# ---> 10 temp()
#      11 print(a)
#
# /tmp/ipykernel_3559/195080578.py in temp()
#       4
#       5 def temp():   # ----> local var
# ----> 6   a += 1
#       7   print(a)
#       8
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
a = 2
# agar hame change karna ho toh global var key used karna hota hai
# toh hum  change kar sakte hai
def temp():
   # ----> local var
  global a
  a += 1
  print(a)


temp()
print(a)
# Out:
# 3
# 3

# %%
# local and global ---> global created inside local

def temp():
  # ----> local var
  global a
  a = 1
  print(a)


temp()
print(a)
# Out:
# 1
# 1

# %%
# local and global --> function parameter is local

def temp(z):
  # local var
  print(z)

a = 5
temp(5)
print(a)
# Out:
# 5
# 5

# %%
# local and global --> function parameter is local

def temp(z):
  # local var
  print(z)

a = 5
temp(5)
print(a)
print(z)
# Out:
# 5
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3559/1300773184.py in <cell line: 0>()
#       8 temp(5)
#       9 print(a)
# ---> 10 print(z)
#
# NameError: name 'z' is not defined

# %%
# built-in-scope

print(dir(__builtins__))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# built-in-scope
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# how to see all the built-ins

# %%
# renaming built-ins
L = [1,2,3]
max(L)
# Out:
# 3

# %%
L = [1,2,3]

def max():
  print('hello')

max(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3559/3981161527.py in <cell line: 0>()
#       4   print('hello')
#       5
# ----> 6 max(L)
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
L = [1,2,3]
max(L)

def max():
  print('hello')

max(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3559/1798126178.py in <cell line: 0>()
#       1 L = [1,2,3]
# ----> 2 max(L)
#       3
#       4 def max():
#       5   print('hello')
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
L = [1,2,3]

def max():
  print('hello')

print(max() )
# Out:
# hello
# None

# %%
# Enclosing scope

def outer():

  def inner():
    print('inner function')
  inner()
  print('outer function')

outer()
print('main program')
# Out:
# inner function
# outer function
# main program

# %%
 # Enclosing scope
def outer():
  a = 3

  def inner():
    a = 4
    print(a)
  inner()
  print('outer function')

a = 1
outer()
print('main program')
# Out:
# 4
# outer function
# main program

# %%
 # Enclosing scope
def outer():
  a = 3

  def inner():

    print(a)
  inner()
  print('outer function')

a = 1
outer()
print('main program')
# Out:
# 3
# outer function
# main program

# %%
 # Enclosing scope
def outer():
  def inner():

    print(a)
  inner()
  print('outer function')

a = 1
outer()
print('main program')
# Out:
# 1
# outer function
# main program

# %%
 # Enclosing scope
def outer():

  def inner():

    print(a)
  inner()
  print('outer function')
outer()
print('main program')
# Out:
# 1
# outer function
# main program
