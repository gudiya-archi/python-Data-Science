# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python_file_handling1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Some theory
#
# * Text - '12345' as a sequence of unicode chars
#
# * Binary - 12345 as a sequence of bytes of its binary equivalent
#
# Hence there are 2 file types to deal with
#
# * Text files = All program files are text files
#
# * Binary files = Images , music , video , exe files

# %% [markdown]
# How File I/O is done in most programming languages
#
# * open a file
# * Read / Write data
# * Close the file

# %% [markdown]
# # Writing to a file

# %%
# case 1 ---> if the file is not present

f = open('sample.txt' , 'w')
f.write('hello world')
# Out:
# 11

# %%
# case 1 ---> if the file is not present

f = open('sample.txt' , 'w')
f.write('hello world')
f.close()

# since file is closed hence this will not work
f.write('hello archi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21520/1699939637.py in <cell line: 0>()
#       6
#       7 # since file is closed hence this will not work
# ----> 8 f.write('hello archi')
#
# ValueError: I/O operation on closed file.

# %%
# write multiline strings
f = open('sample1.txt' , 'w')
f.write('hello archi')
f.write('\nhow are you ?')
f.close()

# %%
# case 2 ---> if the file is already present

# but usme jobhi likha honga woh replace ho jayega
# delete ho jaata hai

f = open('sample.txt' , 'w')
f.write('Archi Jaiswal')
f.close()

# %%
# how exactly open() works ?

# %%
# problem with W mode
# introducing append mode

f = open('/content/sample1.txt', 'a')
f.write('\nI am fine ')
f.close()

# %%
# write lines

L = ['hello\n','hi\n','how are you\n','I am fine']

f = open('/content/sample.txt' , 'w')
f.writelines(L)
f.close()

# %%
# write lines   ---> new folder create ki hai temp
#   aur uske andar sample .text file create kiya

L = ['hello\n','hi\n','how are you\n','I am fine']

f = open('/content/temp/sample.txt' , 'w')
f.writelines(L)
f.close()

# %%
# reading from files
#  ----> using read()
# ----> file ko read kr sakte kaise python me jaise read karte hai
# bur strings formated me hota hai

f = open('/content/sample.txt' , 'r')
s = f.read()
print(s)
f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %%
# reading upto n chars
# only read 10 character bas

f = open('/content/sample.txt' , 'r')
s = f.read( 10 )
print(s)
f.close()
# Out:
# hello
# hi
# h

# %%
# readline() ---> to read line by line
# isme line change hota hai print karne ke baad automatic line change ho jata hai

f = open('/content/sample.txt' , 'r')
print(f.readline())
print(f.readline())
f.close()
# Out:
# hello
#
# hi

# %%
f = open('/content/sample.txt' , 'r')
print(f.readline(),end='')
print(f.readline(),end='')
f.close()
# Out:
# hello
# hi

# %%
# reading entire using readline

f = open('/content/sample.txt' , 'r')

while True:

  data= f.readline()
  if data == '':
    break
  else:
    print(data)
f.close()
# Out:
# hello
#
# hi
#
# how are you
#
# I am fine

# %%
# reading entire using readline
# line change nhi hoti hai end='' this is a syntax

f = open('/content/sample.txt' , 'r')

while True:

  data= f.readline()
  if data == '':
    break
  else:
    print(data,end='')
f.close()
# Out:
# hello
# hi
# how are you
# I am fine

# %% [markdown]
# # Using Context Manager (With)

# %% [markdown]
# * it's a good idea to close a file after usage as it will free up the resources
#
# * if we dont close it, garbage collector would close it
#
# * with keyword closes the file as soon as the usage it over

# %%
# With keyword
with open ('/content/sample1.txt' ,'w') as f:
  f.write('hello archi')

# %%
f.write('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21520/375632407.py in <cell line: 0>()
# ----> 1 f.write('hello')
#
# ValueError: I/O operation on closed file.

# %%
# try f.read() now

with open('/content/sample.txt' , 'r') as f:
  print(f.read())
# Out:
# hello
# hi
# how are you
# I am fine

# %%
# moving within a file ---> 10 char then 10 char
with open('/content/sample.txt' , 'r') as f:
  print(f.read(10))
# Out:
# hello
# hi
# h

# %%
with open('/content/sample.txt' , 'r') as f:
  print(f.read(10))
  print(f.read(10))
# Out:
# hello
# hi
# h
# ow are you

# %%
# benefit ? ---> to load a big file in memory

big_L = ['hello world ' for i in range (1000)]

with open('big.text', 'w') as f :
  f.writelines(big_L)

# %%
# benefit ? ---> to load a big file in memory


with open('big.text','r') as f:

  chunk_size = 100

  while len(f.read(chunk_size)) > 0:
    print(f.read(chunk_size), end='')
    f.read(chunk_size)
# Out:
# o world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello woo world hello world hello world hello world hello world hello world hello world hello world hello 
# ...

# %%
# benefit ? ---> to load a big file in memory


with open('big.text','r') as f:

  chunk_size = 10

  while len(f.read(chunk_size)) > 0:
    print(f.read(chunk_size), end='***')
    f.read(chunk_size)
# Out:
# d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo
# ...

# %%
# seek and tell function
with open ('/content/sample.txt' , 'r') as f:
  print(f.read(10))
  print(f.tell())
# Out:
# hello
# hi
# h
# 10

# %%
# seek and tell function
with open ('/content/sample.txt' , 'r') as f:
  print(f.read(10))
  print(f.tell())
  f.seek(0)
  print(f.read(10))
# Out:
# hello
# hi
# h
# 10
# hello
# hi
# h

# %%
with open ('/content/sample.txt' , 'r') as f:
  print(f.read(10))
  print(f.tell())
  f.seek(0)
  print(f.read(10))
  print(f.tell())
  # seek hum kahi pr bhi used kr sakte hai
# Out:
# hello
# hi
# h
# 10
# hello
# hi
# h
# 10

# %%
with open ('/content/sample.txt' , 'r') as f:
  f.seek(15)
  print(f.read(10))
  print(f.tell())
  print(f.read(10))
  print(f.tell())
  # seek hum kahi pr bhi used kr sakte hai
# Out:
# e you
# I am
# 25
#  fine
# 30

# %%
 # seek during write

with open ('/content/sample.txt' , 'w') as f:
   f.write('hello')
   f.seek(0)
   f.write('Xa')

# %% [markdown]
# # Problems with working in text mode
#
# * can't work with binary files like images
#
# * not good for other data types like int/float/list/tuples

# %%
with open ('/content/kashu10.jpg', 'r') as f :
   f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_21520/1768518850.py in <cell line: 0>()
#       1 with open ('/content/kashu10.jpg', 'r') as f :
# ----> 2    f.read()
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
# working with binary file

with open ('/content/kashu10.jpg','rb') as f :
  with open('/content/kashu10_copy.jpg' , 'wb') as wf:
    wf.write(f.read())

# %%
# working with other data types

with open ('/content/sample.txt','w') as f :
  f.write(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21520/1970218499.py in <cell line: 0>()
#       2
#       3 with open ('/content/sample.txt','w') as f :
# ----> 4   f.write(5)
#
# TypeError: write() argument must be str, not int

# %%
with open ('/content/sample.txt','w') as f :
  f.write('5')

# %%
with open ('/content/sample.txt','r') as f :
  print(int(f.read()) + 5 )
# Out:
# 10

# %%
# working with a big binary file

# %%
 # more complex data

d = {
    'name' : 'Archi',
    'age' : 21,
    'gender': 'female'
}


with open ('/content/sample.txt','w') as f :
  f.write(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21520/3508988624.py in <cell line: 0>()
#       9
#      10 with open ('/content/sample.txt','w') as f :
# ---> 11  f.write(d)
#
# TypeError: write() argument must be str, not dict

# %%
# more complex data

d = {
    'name' : 'Archi',
    'age' : 21,
    'gender': 'female'
}


with open ('/content/sample.txt','w') as f :
  f.write(str(d))

# %%
# more complex data

with open('sample.txt','r') as f :
  print(f.read())
# Out:
# {'name': 'Archi', 'age': 21, 'gender': 'female'}

# %%
# more complex data

with open('sample.txt','r') as f :
  print(f.read())
  print(type(f.read()))
# Out:
# {'name': 'Archi', 'age': 21, 'gender': 'female'}
# <class 'str'>

# %%
with open('sample.txt','r') as f :
  print(dict(f.read()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21520/698887017.py in <cell line: 0>()
#       2
#       3 with open('sample.txt','r') as f :
# ----> 4   print(dict(f.read()))
#       5
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %% [markdown]
# # Serialization and Deserialization
#
# * Serialization - process of converting python data type to JSON format
#
# * Deserialization - process of converting JSON to python data types

# %% [markdown]
# what is json ?
#
# JSON stands for JavaScript object notation

# %%
# Serialization using json module
# list
# L= list , f = file ,file name = demo

import json

L = [1,2,3,4,5]

with open ('demo.json','w') as f :
  json.dump(L,f)

# %%
# dict
import json
d = {
    'name' : 'Archi',
    'age' : 21,
    'gender': 'female'
}

with open ('demo.json','w') as f :
  json.dump(d,f)

# %%
# dict
import json
d = {
    'name' : 'Archi',
    'age' : 21,
    'gender': 'female'
}

with open ('demo.json','w') as f :
  json.dump(d,f,indent=4)

# %%
# deserialization

import json

with open ('demo.json','r') as f :
  print(json.load(f))
# Out:
# {'name': 'Archi', 'age': 21, 'gender': 'female'}

# %%
# deserialization

import json

with open ('demo.json','r') as f :
  d = json.load (f)
  print(d)
  print(type(d))
# Out:
# {'name': 'Archi', 'age': 21, 'gender': 'female'}
# <class 'dict'>

# %%
# serialize and deserialize tuple
# jab bhi hum tuple ko used karte hai but woh list maine converted hota hai

import json

t = (1,2,3,4,5)

with open ('demo_1.json','w') as f :
  json.dump(t,f)

# %%
# serialize and deserialize a nested dict
import json

d = {
    'studenr':'archi',
    'marks': [23,14,34,45,56]
}

with open ('demo_2.json','w') as f :
  json.dump(d,f)

# %%
# serialize and deserialize a nested dict
import json

d = {
    'studenr':'archi',
    'marks': [23,14,34,45,56]
}

with open ('demo_2.json','w') as f :
  json.dump(d,f,indent=4)

# %% [markdown]
# # Serializing and Deserializing custom object

# %%
class Person:
  def __init__(self,fname,lname,age,gender):
    self.fname = fname
    self.lname = lname
    self.age = age
    self.gender = gender

    # format to printed in
    # ----> Archi Jaiswal  , age --> 22 , gender --> female

# %%
person = Person ('Archi','Jaiswal',22,'female')

# %%
# As a string

import json
with open ('demo_5.json','w') as f :
   json.dump(person,f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7758/1216671590.py in <cell line: 0>()
#       3 import json
#       4 with open ('demo_5.json','w') as f :
# ----> 5    json.dump(person,f)
#
# /usr/lib/python3.12/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /usr/lib/python3.12/json/encoder.py in _iterencode(o, _current_indent_level)
#     437                     raise ValueError("Circular reference detected")
#     438                 markers[markerid] = o
# --> 439             o = _default(o)
#     440             yield from _iterencode(o, _current_indent_level)
# ...

# %%
# As a string

import json

def show_object(person):
  if isinstance(person,Person):
    return "{} {} age --> {} gender --> {}".format(person.fname,person.lname,person.age,person.gender)


with open ('demo_5.json','w') as f :
   json.dump(person,f,default=show_object)

# %%
# As a dict

import json

def show_object(person):
  if isinstance(person,Person):
    return {'name':person.fname + " " + person.lname,'age':person.age,'gender':person.gender}


with open ('demo_5.json','w') as f :
   json.dump(person,f,default=show_object,indent=4)

# %%
# indent arrtribute
# as a dict

# %%
# deserializing

import json
with open ('demo_5.json','r') as f :
  print(json.load(f))
# Out:
# {'name': 'Archi Jaiswal', 'age': 22, 'gender': 'female'}

# %%
import json
with open ('demo_5.json','r') as f :
  d = json.load(f )
  print(d)
  print(type(d))
# Out:
# {'name': 'Archi Jaiswal', 'age': 22, 'gender': 'female'}
# <class 'dict'>

# %% [markdown]
# # Pickling
#
# * Pickling is the process where by a python object hierarchy is converted into a byte strem, and unpickling is the inverse operation , where by a byte stream ( from a binary file or bytes-like object ) is converted back into an object hierarchy

# %%
class Person:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display_info(self):
    print('Hi my name is',self.name,'and I am ',self.age,'year old')

# %%
p = Person('Archi',22)

# %%
# pickle dump
import pickle
with open ('person.pkl','wb') as f :
  pickle.dump(p,f)

# %%
# pickle dump
import pickle
with open ('person.pkl','rb') as f :
  p = pickle.load(f)
  p.display_info()

# %% [markdown]
# #   pickle vs json
#
#  *  pickle lets the user to store data in binary format. json lets the user store data in a human-readable text format
