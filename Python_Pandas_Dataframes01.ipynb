# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python_Pandas_Dataframes01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 17

# %% [markdown]
# * ipl-matches.csv
# * movies.csv

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating DataFrame
#
# * using lists
# * using dicts
# * using read_csv

# %%
# using lists ---> 2D lists

student_data =[
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data, columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using dicts

student_data = {
    'iq':[100,90,120,80],
    'marks':[80,70,100,50],
    'package':[10,7,14,2]
}

students = pd.DataFrame(student_data)
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# using read_csv
movies = pd.read_csv('/content/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # DataFrame Attributes and Methods
#
# * shape
# * dtype
# * index
# * columns
# * values
# * head and tail
# * sample
# * info

# %%
# shape
print(movies.shape) # rows 1629 , columns 18
print(ipl.shape) # rows 950 , columns 20
# Out:
# (1629, 18)
# (950, 20)

# %%
# dtypes
print(movies.dtypes)
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
print(ipl.dtypes)
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
print(movies.index)
print(ipl.index)
# Out:
# RangeIndex(start=0, stop=1629, step=1)
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
print(movies.columns)
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# columns
print(ipl.columns)
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
# columns
students.columns
# Out:
# Index(['iq', 'marks', 'package'], dtype='object')

# %%
# values
students.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120, 100,  14],
#        [ 80,  50,   2]])

# %%
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
# head and tail
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.head(7)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# ...

# %%
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %%
movies.tail(3)
# Out:
#               title_x     imdb_id  \
# 1626  Sabse Bada Sukh   tt0069204
# 1627            Daaka  tt10833860
# 1628         Humsafar   tt2403201
#
#                                             poster_path  \
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link          title_y  \
# 1626  https://en.wikipedia.org/wiki/Sabse_Bada_Sukh  Sabse Bada Sukh
# 1627            https://en.wikipedia.org/wiki/Daaka            Daaka
# 1628         https://en.wikipedia.org/wiki/Humsafar         Humsafar
#
#        original_title  is_adult  year_of_release runtime         genres  \
# 1626  Sabse Bada Sukh         0             2018      \N   Comedy|Drama
# 1627            Daaka         0             2019     136         Action
# 1628         Humsafar         0             2011      35  Drama|Romance
#
# ...

# %%
# sample
movies.sample()
# Out:
#        title_x    imdb_id                                        poster_path  \
# 427  Bangistan  tt3422462  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                    wiki_link    title_y original_title  \
# 427  https://en.wikipedia.org/wiki/Bangistan  Bangistan      Bangistan
#
#      is_adult  year_of_release runtime        genres  imdb_rating  imdb_votes  \
# 427         0             2015     135  Comedy|Drama          4.6         992
#
#                                                  story  \
# 427  Bangistan is a whip smart and uproarious satir...
#
#                                                summary tagline  \
# 427  Two blundering terrorists with lofty ideologie...     NaN
#
#                                                 actors wins_nominations  \
# 427  Jacqueline Fernandez|Riteish Deshmukh|Michalin...     1 nomination
#
#             release_date
# 427  7 August 2015 (USA)

# %%
movies.sample(5)
# Out:
#                                title_x    imdb_id  \
# 1576  Aamdani Atthanni Kharcha Rupaiya  tt0305173
# 297                        Udta Punjab  tt4434004
# 457                             Gunday  tt2574698
# 267                       Ishq Forever  tt4979160
# 565                Main Aur Mr. Riight  tt2216852
#
#                                             poster_path  \
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 297   https://upload.wikimedia.org/wikipedia/en/thum...
# 457   https://upload.wikimedia.org/wikipedia/en/thum...
# 267   https://upload.wikimedia.org/wikipedia/en/thum...
# 565   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1576  https://en.wikipedia.org/wiki/Aamdani_Atthanni...
# 297           https://en.wikipedia.org/wiki/Udta_Punjab
# 457                https://en.wikipedia.org/wiki/Gunday
# 267          https://en.wikipedia.org/wiki/Ishq_Forever
# ...

# %% [markdown]
# # info
#
# * info() DataFrame ke columns , data types, non-null values aur memory usage ki information show karta hai

# %%
import pandas as pd
data = {
    'name': ['wonder', 'shiv', 'nishant', 'prakhar'],
    'age': [25, 30, 56,78]
}
df = pd.DataFrame(data)
df
# Out:
#       name  age
# 0   wonder   25
# 1     shiv   30
# 2  nishant   56
# 3  prakhar   78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %% [markdown]
# *  RangeIndex ---> total rows
# *  Data columns --->  total columns
# *  Non-Null Count ---> kitni values missing nhi hai
# *  Dtype ---> Data type (int64 , object etc. )
# * Memory usage ---> kini memory use ho rahi hai
#
#
# # Non-Null Count = total rows - missing values

# %%
# info

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
df.describe()
# Out:
#              age
# count   4.000000
# mean   47.250000
# std    24.595054
# min    25.000000
# 25%    28.750000
# 50%    43.000000
# 75%    61.500000
# max    78.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %% [markdown]
# # isnull
#
# * isnull() missing values (NaN , None ) ko detect karta hai
#
# * Agar value missing hai ---> True
# * Agar value present hai ---> False
#
# # Normal value ---> false
# # Missing value (None , NaN ) ---> True

# %%
df.isnull()
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
movies.isnull()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %% [markdown]
# # isnull

# %%
import pandas as pd

data = {
    "Name": ["Alia", None, "Sara"],
    "Age": [22, 21, None]
}

temp = pd.DataFrame(data)
temp
# Out:
#    Name   Age
# 0  Alia  22.0
# 1  None  21.0
# 2  Sara   NaN

# %%
print(temp.isnull())
# Out:
#     Name    Age
# 0  False  False
# 1   True  False
# 2  False   True

# %%
temp.isnull().sum()
# Out:
# Name    1
# Age     1
# dtype: int64

# %%
# isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# name    0
# age     0
# dtype: int64

# %%
temp.isnull().sum()
# Out:
# Name    1
# Age     1
# dtype: int64

# %% [markdown]
# # duplicated
#
# * duplicate rows ko identify karta hai
#
# * duplicate row --> True
# * Unique row --> Fales

# %%
# duplicated
temp.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
movies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
ipl.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
temp.duplicated().sum()
# Out:
# np.int64(0)

# %%
students.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# using dicts

student_data = {
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50, 0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_data)
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# 4    0      0        0
# 5    0      0        0

# %%
students.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# # rename()
#
# * rename () existing columns ya index ka naam change karta hai

# %% [markdown]
# # rename ---> name change
#
# * columns= column ka naam
# * index=   row index ka naam
# * inplace=True ---> original data ko change

# %%
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# 4    0      0        0
# 5    0      0        0

# %%
students.rename(columns={'marks': 'percent', 'package': 'lpi'})
# Out:
#     iq  percent  lpi
# 0  100       80   10
# 1   90       70    7
# 2  120      100   14
# 3   80       50    2
# 4    0        0    0
# 5    0        0    0

# %%
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
# 4    0      0        0
# 5    0      0        0

# %%
students.rename(columns={'marks': 'percent', 'package': 'lpi'}, inplace=True)

# %%
students
# Out:
#     iq  percent  lpi
# 0  100       80   10
# 1   90       70    7
# 2  120      100   14
# 3   80       50    2
# 4    0        0    0
# 5    0        0    0

# %%
students.rename(index={0:'first', 1:'second', 2:'third', 3:'fourth', 4:'fifth', 5:'sixth'})
# Out:
#          iq  percent  lpi
# first   100       80   10
# second   90       70    7
# third   120      100   14
# fourth   80       50    2
# fifth     0        0    0
# sixth     0        0    0

# %%
students.rename(index={0:'first', 1:'second', 2:'third', 3:'fourth', 4:'fifth', 5:'sixth'},inplace=True)

# %%
students
# Out:
#          iq  percent  lpi
# first   100       80   10
# second   90       70    7
# third   120      100   14
# fourth   80       50    2
# fifth     0        0    0
# sixth     0        0    0

# %% [markdown]
# # Math Methods

# %% [markdown]
# sum ---> axis argument

# %%
movies.sum(numeric_only=True)
# Out:
# is_adult                 0.0
# year_of_release    3274720.0
# imdb_rating           9053.1
# imdb_votes         8770965.0
# dtype: float64

# %%
students.sum()
# Out:
# iq         390
# percent    300
# lpi         33
# dtype: int64

# %%
students
# Out:
#          iq  percent  lpi
# first   100       80   10
# second   90       70    7
# third   120      100   14
# fourth   80       50    2
# fifth     0        0    0
# sixth     0        0    0

# %%
# sum --> axis argument
students.sum(axis=1)  # ---- row
# Out:
# first     190
# second    167
# third     234
# fourth    132
# fifth       0
# sixth       0
# dtype: int64

# %%
students.sum(axis=0)  # ---> columns
# Out:
# iq         390
# percent    300
# lpi         33
# dtype: int64

# %% [markdown]
# # mean

# %%
students.mean()
# Out:
# iq         65.0
# percent    50.0
# lpi         5.5
# dtype: float64

# %%
students.mean(axis=1)   # ----> rows
# Out:
# first     63.333333
# second    55.666667
# third     78.000000
# fourth    44.000000
# fifth      0.000000
# sixth      0.000000
# dtype: float64

# %%
students.mean(axis=0)   # ----> columns
# Out:
# iq         65.0
# percent    50.0
# lpi         5.5
# dtype: float64

# %% [markdown]
# * min
# * max
# * median
# * std
# * var
# * mean
# * mode

# %%
print(  students.min()  )
print(  students.max()  )
print(  students.median() )
print(  students.std()  )
print(  students.var()  )
print(  students.mode())
print ( students.mean())
# Out:
# iq         0
# percent    0
# lpi        0
# dtype: int64
# iq         120
# percent    100
# lpi         14
# dtype: int64
# iq         85.0
# percent    60.0
# lpi         4.5
# dtype: float64
# iq         52.057660
# percent    41.952354
# lpi         5.787918
# dtype: float64
# iq         2710.0
# percent    1760.0
# lpi          33.5
# dtype: float64
#    iq  percent  lpi
# 0   0        0    0
# iq         65.0
# percent    50.0
# lpi         5.5
# dtype: float64

# %% [markdown]
# # Selecting cols from a DataFrame
#
# # single cols
#
# * single cols ke liye series used hota hai

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
movies['title_x'].head(3)
# Out:
# 0                Uri: The Surgical Strike
# 1                           Battalion 609
# 2    The Accidental Prime Minister (film)
# Name: title_x, dtype: object

# %%
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
type(ipl['Venue'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # multiple cols
#
# * multiple ke liye DataFrame used hota hai
#
# * aur ham apne hisab se order maine set kar sakte hai

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# muliple cols

movies[['title_x', 'title_y']]
# Out:
#                                    title_x                        title_y
# 0                 Uri: The Surgical Strike       Uri: The Surgical Strike
# 1                            Battalion 609                  Battalion 609
# 2     The Accidental Prime Minister (film)  The Accidental Prime Minister
# 3                          Why Cheat India                Why Cheat India
# 4                          Evening Shadows                Evening Shadows
# ...                                    ...                            ...
# 1624                 Tera Mera Saath Rahen          Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar           Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh                Sabse Bada Sukh
# 1627                                 Daaka                          Daaka
# 1628                              Humsafar                       Humsafar
#
# [1629 rows x 2 columns]

# %%
movies[['title_x', 'year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
movies[['title_x', 'year_of_release','actors']].head(3)
# Out:
#                                 title_x  year_of_release  \
# 0              Uri: The Surgical Strike             2019
# 1                         Battalion 609             2019
# 2  The Accidental Prime Minister (film)             2019
#
#                                               actors
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...

# %%
type(movies[['title_x', 'year_of_release','actors']])
# Out:
# pandas.core.frame.DataFrame

# %%
movies[[ 'year_of_release','actors', 'title_y','title_x']]
# Out:
#       year_of_release                                             actors  \
# 0                2019  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1                2019  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2                2019  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3                2019  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4                2018  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...               ...                                                ...
# 1624             2001  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625             2001  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626             2018  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627             2019                          Gippy Grewal|Zareen Khan|
# 1628             2011                                        Fawad Khan|
#
#                             title_y                               title_x
# ...

# %% [markdown]
# # Selecting rows from a DataFrame

# %%
# using dicts

student_data = {
    'name': ['wonder', 'shiv', 'nishant', 'prakhar', 'aman', 'amit'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50, 0,0],
    'package':[10,7,14,2,0,0]
}

students = pd.DataFrame(student_data)
students
# Out:
#       name   iq  marks  package
# 0   wonder  100     80       10
# 1     shiv   90     70        7
# 2  nishant  120    100       14
# 3  prakhar   80     50        2
# 4     aman    0      0        0
# 5     amit    0      0        0

# %%
students.set_index('name')
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# shiv      90     70        7
# nishant  120    100       14
# prakhar   80     50        2
# aman       0      0        0
# amit       0      0        0

# %%
students.set_index('name', inplace=True)

# %%
students
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# shiv      90     70        7
# nishant  120    100       14
# prakhar   80     50        2
# aman       0      0        0
# amit       0      0        0

# %% [markdown]
# # Selecting rows from a DataFrame
#
# # iloc ---> searches using index positions
#
# # loc ---> searches using index labels

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# single row
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
type(movies.iloc[0])
# Out:
# pandas.core.series.Series

# %%
# multiple row
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.iloc[5:16]
# Out:
#                              title_x    imdb_id  \
# 5                        Soni (film)  tt6078866
# 6                      Fraud Saiyaan  tt5013008
# 7                         Bombairiya  tt4971258
# 8   Manikarnika: The Queen of Jhansi  tt6903440
# 9                   Thackeray (film)  tt7777196
# 10                            Amavas  tt8396186
# 11                         Gully Boy  tt2395469
# 12                         Hum Chaar  tt9319812
# 13                     Total Dhamaal  tt7639372
# 14                        Sonchiriya  tt8108200
# 15                 Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
type(movies.iloc[5:16])
# Out:
# pandas.core.frame.DataFrame

# %%
movies.iloc[5:16:2]
# Out:
#               title_x    imdb_id  \
# 5         Soni (film)  tt6078866
# 7          Bombairiya  tt4971258
# 9    Thackeray (film)  tt7777196
# 11          Gully Boy  tt2395469
# 13      Total Dhamaal  tt7639372
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link        title_y  \
# 5         https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 7          https://en.wikipedia.org/wiki/Bombairiya     Bombairiya
# 9    https://en.wikipedia.org/wiki/Thackeray_(film)      Thackeray
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# ...

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %% [markdown]
# # loc ---> lables

# %%
students
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# shiv      90     70        7
# nishant  120    100       14
# prakhar   80     50        2
# aman       0      0        0
# amit       0      0        0

# %%
students.loc['wonder']
# Out:
# iq         100
# marks       80
# package     10
# Name: wonder, dtype: int64

# %%
students.loc['wonder':'prakhar']
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# shiv      90     70        7
# nishant  120    100       14
# prakhar   80     50        2

# %%
students.loc['wonder':'prakhar':2]
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# nishant  120    100       14

# %%
students.loc[['wonder','prakhar','shiv']]
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# prakhar   80     50        2
# shiv      90     70        7

# %%
students.iloc[0]
# Out:
# iq         100
# marks       80
# package     10
# Name: wonder, dtype: int64

# %%
students.iloc[0:5]
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# shiv      90     70        7
# nishant  120    100       14
# prakhar   80     50        2
# aman       0      0        0

# %%
students.iloc[0:5:2]
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# nishant  120    100       14
# aman       0      0        0

# %%
students.iloc[[0,3,1, 4]]
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# prakhar   80     50        2
# shiv      90     70        7
# aman       0      0        0

# %%
students
# Out:
#           iq  marks  package
# name
# wonder   100     80       10
# shiv      90     70        7
# nishant  120    100       14
# prakhar   80     50        2
# aman       0      0        0
# amit       0      0        0

# %% [markdown]
# # Selecting both rows and cols

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.iloc[0:3,0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y
# 0       Uri: The Surgical Strike
# 1                  Battalion 609
# 2  The Accidental Prime Minister

# %%
movies.loc[0:3, 'title_x':'title_y']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y
# 0       Uri: The Surgical Strike
# 1                  Battalion 609
# 2  The Accidental Prime Minister
# ...

# %%
movies.loc[0:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
