# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python_Pandas_Series01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Series using read_csv

# %% [markdown]
# Session_16 dataset hai .....csv file ka
# 1.  bollywood.csv
# 2.  kohli_ipl.csv
# 3.  subs.csv

# %%
import numpy as np
import pandas as pd

# %%
# with one cols
pd.read_csv('/content/subs.csv')
#    ....Dataframe maine aata hai

# squeeze=True hai toh Series banne ga
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(pd.read_csv('/content/subs.csv'))
# Out:
# pandas.core.frame.DataFrame

# %%
subs = pd.read_csv('/content/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# with 2 cols
pd.read_csv('/content/kohli_ipl.csv')
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv', index_col='match_no')
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movies = pd.read_csv('/content/bollywood.csv', index_col='movie')
movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# # Series Methods

# %%
# head and tail
subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.head(3)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40

# %%
vk.tail()
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
vk.tail(10)
# Out:
#           runs
# match_no
# 206          0
# 207          0
# 208          9
# 209         58
# 210         30
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
# sample ----> random number nikal kr deta hai

movies.sample()
# Out:
#                                  lead
# movie
# Kuch Naa Kaho  Aishwarya Rai Bachchan

# %%
movies.sample(5)
# Out:
#                                         lead
# movie
# Once Upon a Time in Mumbaai       Ajay Devgn
# Police Force: An Inside Story   Akshay Kumar
# Rocky Handsome                  John Abraham
# Dil Maange More                Shahid Kapoor
# Ragini MMS 2                     Sunny Leone

# %%
# value_counts  ----> movies -----> frequency count karta hai
#   ----> descending order

movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values ----> inplace
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
# sort_values ---> inplace ascending order mein
vk.sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36216/2059085118.py in <cell line: 0>()
#       1 # sort_values ---> inplace ascending order mein
# ----> 2 vk.sort_values()
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
vk.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36216/910477176.py in <cell line: 0>()
# ----> 1 vk.sort_values(ascending=False)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
vk.sort_values(ascending=False).head(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36216/1321904933.py in <cell line: 0>()
# ----> 1 vk.sort_values(ascending=False).head(1)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
vk.sort_values(ascending=False).head(1).value[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36216/604172671.py in <cell line: 0>()
# ----> 1 vk.sort_values(ascending=False).head(1).value[0]
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
# sort_values(inplace=True) ----> original value ko change karta hai

vk.sort_values(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_36216/2249684890.py in <cell line: 0>()
#       1 # sort_values(inplace=True) ----> original value ko change karta hai
#       2
# ----> 3 vk.sort_values(inplace=True)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
 # sort_index ---> inplace ---> movies
 movies
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
# sort_index ---> inplace ---> movies
movies.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %%
movies.sort_index()
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %%
movies.sort_index(inplace=True)

# %%
movies
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# # Series maths methods
#
# * count
# * sum ---> product
# * mean ---> median ---> mode ---> std ---> var
# * min / max
# * describe

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %%
# sum ---> product
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
# mean , median , mode , std , var

print(subs.mean())
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# Subscribers gained    135.643836
# dtype: float64
# runs    24.0
# dtype: float64
#            lead
# 0  Akshay Kumar
# Subscribers gained    62.675023
# dtype: float64
# runs    688.002478
# dtype: float64

# %%
# min / max

print (subs.min())
print (subs.max())
# Out:
# Subscribers gained    33
# dtype: int64
# Subscribers gained    396
# dtype: int64

# %%
# describe ---> mathematical batata hai
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %%
subs.describe()
# Out:
#        Subscribers gained
# count          365.000000
# mean           135.643836
# std             62.675023
# min             33.000000
# 25%             88.000000
# 50%            123.000000
# 75%            177.000000
# max            396.000000

# %%
movies.describe()
# Out:
#                 lead
# count           1500
# unique           566
# top     Akshay Kumar
# freq              48

# %% [markdown]
# # Series Indexing

# %% [markdown]
# * integer indexing
# * negative indexing
# * slicing
# * negative slicing
# * fancy indexing
# * indexing with lables ---> fancy indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x[0]
# Out:
# np.int64(12)

# %%
x[3]
# Out:
# np.int64(35)

# %%
# negative indexing
# ---> pandas maine Seriers indexing kaam nhi karta hai
# .....is should be a error.--->string
x [-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_36216/1035664948.py in <cell line: 0>()
#       2 # ---> pandas maine Seriers indexing kaam nhi karta hai
#       3 # .....is should be a error.--->string
# ----> 4 x [-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
# ...

# %%
movies
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %%
movies[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_36216/3901301928.py in <cell line: 0>()
# ----> 1 movies[0]
#
# ...

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
# slicing
vk[5:16]
# Out:
#           runs
# match_no
# 6            9
# 7           34
# 8            0
# 9           21
# 10           3
# 11          10
# 12          38
# 13           3
# 14          11
# 15          50
# 16           2

# %%
# negative slicing
vk [-5:]
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %%
movies[-5:]
# Out:
#                                         lead
# movie
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav

# %%
movies[::2]
# Out:
#                                       lead
# movie
# 1920 (film)               Rajniesh Duggall
# 1920: The Evil Returns         Vicky Ahuja
# 2 States (2014 film)          Arjun Kapoor
# 3 A.M. (2014 film)           Salil Acharya
# 3 Idiots                        Aamir Khan
# ...                                    ...
# Zero (2018 film)            Shah Rukh Khan
# Zila Ghaziabad                Vivek Oberoi
# Zindaggi Rocks                Sushmita Sen
# Zindagi Na Milegi Dobara    Hrithik Roshan
# Zokkomon                   Darsheel Safary
#
# [750 rows x 1 columns]

# %%
# fancy indexing ---> right code hai Series
vk[[1,3,4,5]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_36216/4044741837.py in <cell line: 0>()
#       1 # fancy indexing ---> right code hai Series
# ----> 2 vk[[1,3,4,5]]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
# indexing with lables ---> fancy indexing ----> right code hai
movies['Zindagi 50-50']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Zindagi 50-50'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_36216/1429467044.py in <cell line: 0>()
# ...

# %%
# indexing with lables ---> fancy indexing
movies['2 states (2014 film )']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2 states (2014 film )'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_36216/2600924447.py in <cell line: 0>()
#       1 # indexing with lables ---> fancy indexing
# ...

# %% [markdown]
# # Editing Series

# %% [markdown]
# * using indexing
# * what if an index does not exist
# * slicing
# * fancy indexing
# * using index lable

# %%
marks = {
    'math':67,
    'science':57,
    'english':89,
    'hindi':100

    }


marks_series = pd.Series(marks, name = 'archi ke marks')
marks_series
# Out:
# math        67
# science     57
# english     89
# hindi      100
# Name: archi ke marks, dtype: int64

# %%
# using indexing ----> columns ko change kr sakte hai
marks_series[1] = 100
marks_series
# Out:
# /tmp/ipykernel_36216/335213510.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# math        67
# science    100
# english     89
# hindi      100
# sst         90
# Name: archi ke marks, dtype: int64

# %%
# what if an index  does not exist
#  ---> yeh error nhi aayenga ---> event yeh add ho jayenga
marks_series['sst'] = 90

# %%
marks_series
# Out:
# math        67
# science    100
# english     89
# hindi      100
# sst         90
# Name: archi ke marks, dtype: int64

# %%
marks_series ['python'] = 89

# %%
marks_series
# Out:
# math        67
# science    100
# english     89
# hindi      100
# sst         90
# python      89
# Name: archi ke marks, dtype: int64

# %%
# slicing
runs = [13,24,56,78,100]
runs_series = pd.Series(runs, name = 'runs scored by kohli')
runs_series
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# Name: runs scored by kohli, dtype: int64

# %%
runs_series[2:4] = [99,99]
runs_series
# Out:
# 0     13
# 1     24
# 2     99
# 3     99
# 4    100
# Name: runs scored by kohli, dtype: int64

# %%
# fancy indexing ---> edit kr diya
runs_series[[0,3,4]] = [0,0,0]
runs_series
# Out:
# 0     0
# 1    24
# 2    99
# 3     0
# 4     0
# Name: runs scored by kohli, dtype: int64

# %%
movies
# Out:
#                                         lead 2 States (2014 film)  \
# movie
# 1920 (film)                 Rajniesh Duggall           Alia bhatt
# 1920: London                   Sharman Joshi           Alia bhatt
# 1920: The Evil Returns           Vicky Ahuja           Alia bhatt
# 1971 (2007 film)              Manoj Bajpayee           Alia bhatt
# 2 States (2014 film)            Arjun Kapoor           Alia bhatt
# ...                                      ...                  ...
# Zindagi 50-50                    Veena Malik           Alia bhatt
# Zindagi Na Milegi Dobara      Hrithik Roshan           Alia bhatt
# Zindagi Tere Naam         Mithun Chakraborty           Alia bhatt
# Zokkomon                     Darsheel Safary           Alia bhatt
# Zor Lagaa Ke...Haiya!          Meghan Jadhav           Alia bhatt
#
#                          (2 States (2014 film), lead)
# movie
# 1920 (film)                                Alia bhatt
# ...

# %%
# using index label
movies ['2 States (2014 film)' ] = 'Alia bhatt'
movies
# Out:
#                                         lead 2 States (2014 film)  \
# movie
# 1920 (film)                 Rajniesh Duggall           Alia bhatt
# 1920: London                   Sharman Joshi           Alia bhatt
# 1920: The Evil Returns           Vicky Ahuja           Alia bhatt
# 1971 (2007 film)              Manoj Bajpayee           Alia bhatt
# 2 States (2014 film)            Arjun Kapoor           Alia bhatt
# ...                                      ...                  ...
# Zindagi 50-50                    Veena Malik           Alia bhatt
# Zindagi Na Milegi Dobara      Hrithik Roshan           Alia bhatt
# Zindagi Tere Naam         Mithun Chakraborty           Alia bhatt
# Zokkomon                     Darsheel Safary           Alia bhatt
# Zor Lagaa Ke...Haiya!          Meghan Jadhav           Alia bhatt
#
#                          (2 States (2014 film), lead)
# movie
# 1920 (film)                                Alia bhatt
# ...

# %% [markdown]
# # Series with python functionalities
#
# * len / type / dir / sorted / max / min
# * type conversion
# * membrship operator
# * looping
# * Arithemetic operators
# * Relational operators

# %%
print (len (subs))
print (type (subs))
print (dir (subs))
print(sorted (subs))
print (max (subs))
print (min (subs))
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
marks_series
# Out:
# math        67
# science    100
# english     89
# hindi      100
# sst         90
# python      89
# Name: archi ke marks, dtype: int64

# %%
# type conversion ----> list maine add karta hai
list(marks_series)
# Out:
# [67, 100, 89, 100, 90, 89]

# %%
# type conversion ----> dict maine add karta hai
dict(marks_series)
# Out:
# {'math': np.int64(67),
#  'science': np.int64(100),
#  'english': np.int64(89),
#  'hindi': np.int64(100),
#  'sst': np.int64(90),
#  'python': np.int64(89)}

# %%
tv = pd.read_csv('/content/bollywood.csv', index_col='movie')
tv
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
# membership operator ----> indes mein serach karta hai
# answer true hai but series mein true rahga
'Company (film)' in tv
# Out:
# False

# %%
'Akshay Kumar' in tv.values
# Out:
# True

# %%
# looping
for i in tv :
  print(i)
# Out:
# lead

# %%
# looping
for i in tv.index :
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic operators (braodcasting )
100 - marks_series
# Out:
# math       33
# science     0
# english    11
# hindi       0
# sst        10
# python     11
# Name: archi ke marks, dtype: int64

# %%
100 + marks_series
# Out:
# math       167
# science    200
# english    189
# hindi      200
# sst        190
# python     189
# Name: archi ke marks, dtype: int64

# %%
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
# relational operator
vk >= 50
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %% [markdown]
# # Boolean indexing on series
#
# * find number of 50's and 100's scored by kohil
# * find number of ducks
# * count number of day when i had more than 200 subs a day
# * find actors who have done more than 20 movies

# %%
# find number of 50's and 100's scored by kohil
vk >= 50
# vk[(vk == 50) | (vk == 100)]
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212       False
# 213        True
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %%
vk[vk >= 50]
# Out:
#           runs
# match_no
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 211        NaN
# 212        NaN
# 213       73.0
# 214        NaN
# 215        NaN
#
# [215 rows x 1 columns]

# %%
vk[vk >= 50].size
# Out:
# 215

# %%
# find number of ducks
vk == 0
# Out:
#            runs
# match_no
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# ...         ...
# 211        True
# 212       False
# 213       False
# 214       False
# 215       False
#
# [215 rows x 1 columns]

# %%
vk [vk == 0].size
# Out:
# 215

# %%
# count number of day when i had more than 200 subs a day
subs > 200
# Out:
#      Subscribers gained
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 360                True
# 361                True
# 362               False
# 363               False
# 364               False
#
# [365 rows x 1 columns]

# %%
subs [subs > 200]. size
# Out:
# 365

# %%
# find actors who have done more than 20 tv
tv
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %%
tv.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
num_tv = tv.value_counts()
num_tv
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
num_tv = tv.value_counts()
num_tv > 20
# Out:
# lead
# Akshay Kumar         True
# Amitabh Bachchan     True
# Ajay Devgn           True
# Salman Khan          True
# Sanjay Dutt          True
#                     ...
# Naveen Bawa         False
# Naushaad Abbas      False
# Nauheed Cyrusi      False
# Natalia Janoszek    False
# Nishikant Kamat     False
# Name: count, Length: 566, dtype: bool

# %%
num_tv = tv.value_counts()
num_tv > 20
# Out:
# lead
# Akshay Kumar         True
# Amitabh Bachchan     True
# Ajay Devgn           True
# Salman Khan          True
# Sanjay Dutt          True
#                     ...
# Naveen Bawa         False
# Naushaad Abbas      False
# Nauheed Cyrusi      False
# Natalia Janoszek    False
# Nishikant Kamat     False
# Name: count, Length: 566, dtype: bool

# %%
num_tv = tv.value_counts()
num_tv[num_tv > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# # Plotting graphs on series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
tv.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Naveen Bawa          1
# Naushaad Abbas       1
# Nauheed Cyrusi       1
# Natalia Janoszek     1
# Nishikant Kamat      1
# Name: count, Length: 566, dtype: int64

# %%
tv.value_counts().head(20)
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
# Shah Rukh Khan        22
# Emraan Hashmi         21
# Saif Ali Khan         18
# John Abraham          18
# Shahid Kapoor         17
# Sunny Deol            17
# Jimmy Sheirgill       16
# Tusshar Kapoor        16
# Irrfan Khan           14
# Manoj Bajpayee        14
# Arjun Rampal          14
# Anupam Kher           13
# Ayushmann Khurrana    12
# Naseeruddin Shah      12
# Kangana Ranaut        12
# Name: count, dtype: int64

# %%
tv.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
tv.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
