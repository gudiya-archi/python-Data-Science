# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/python-Data-Science/blob/main/Python03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. if-else in python

# %%
# login program and indentation

# email ---> archijaiswal461@gmail.com
# password ---> 1234

email = input('enter email')
password = input('enter password')

if email == 'archijaiswal461@gmail.com' and password == '1234':
  print('welcome')
  #print('you are logged in')
else:
  print(' Not correct, please check your email and password')
# Out:
# enter emailarchijaiswal461@gmail.com
# enter password1234
# welcome

# %%
# email ---> archijaiswal461@gmail.com
# password ---> 1234

email = input('enter email')
password = input('enter password')

if email == 'archijaiswal461@gmail.com' and password == '1234':
  print('welcome')

elif email == 'archijaiswal461@gmail.com' and password != '1234':
  # tell the user
  print('password incorrect')
  password = input('enter password again')
  if password == '1234':
    print(' Welcome ,Finally correct')

  else:
    print('beta tumse na ho paayega ')

else:
  print(' Not correct, please check your email and password')
# Out:
# enter emailarchijaiswal461@gmail.com
# enter password5678
# password incorrect
# enter password again5678
# beta tumse na ho paayega

# %%
# if-else examples
# 1. find the main of 3 given numbers
# 2. menu driver program

# %%
# min of 3 number

a = int(input('enter first number'))
b = int(input('enter second number'))
c = int(input('enter third number'))

if a<b and a<c:
  print('smallest is',a)
elif b<c:
  print('smallest is',b)
else:
  print('smallest is',c)
# Out:
# enter first number7
# enter second number8
# enter third number9
# smallest is 7

# %%
# menu driven calculator

fnum = int(input('enter first number'))

snum = int(input('enter second number'))

op = input('enter the operation')

if op == '+':
  print(fnum + snum)
elif op == '-':
  print(fnum - snum)
elif op == '*':
  print(fnum * snum)

else:
  print (fnum / snum)
# Out:
# enter first number9
# enter second number9
# enter the operation+
# 18

# %%
# menu driven calculator

menu = input("""
Hi! how can I help you.
1. Enter 1 for pin change
2  Enter 2 for balance check
3. Enter 3 for withdrawl
4. Enter 4 for exit
""")

if menu == '1':
  print('pin change')
elif menu == '2':
  print('balance check')

else:
  print ('exit')
# Out:
# Hi! how can I help you.
# 1. Enter 1 for pin change
# 2  Enter 2 for balance check
# 3. Enter 3 for withdrawl
# 4. Enter 4 for exit
# 1
# pin change

# %% [markdown]
# Modules in python

# %% [markdown]
# * math
# * keywords
# * random
# * datetime

# %%
# math
import math

math.factorial(5)
# Out:
# 120

# %%
math.floor(6.8)
# Out:
# 6

# %%
math.sqrt(196)
# Out:
# 14.0

# %%
 # keyword

 import keyword
 print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 92

# %%
# Datetime

import datetime
print(datetime.datetime.now())
# Out:
# 2026-04-02 11:29:15.565880
